# %%
import sys
import os

# This tells the notebook to look one folder up (to find the src folder)
sys.path.append(os.path.abspath(os.path.join('..')))

# Now you can import your function
from src.thermodynamic_analysis import analyze_madeira_fohen_effect

# Run the analysis
analyzer = analyze_madeira_fohen_effect()

# Display the plot
analyzer.show()

# Save the figure to the outputs folder
analyzer.save_figure('../outputs/skewt_diagram.png', dpi=300)
# Out:
# ...
# FÖHN EFFECT ANALYSIS - MADEIRA ISLAND
# ...
#
# Windward Side (North Coast):
#   Temperature: 20°C
#   Dewpoint: 10.5°C
#   Mixing Ratio: 8 g/kg
#
# Orographic Lifting:
#   LCL (Cloud Base): 870 hPa, 8.4°C
#   Summit: 400 hPa, -32°C
#   LCL (Descent): 655 hPa, -4.5°C
#
# Leeward Side (Funchal - South Coast):
#   Temperature: 30°C
#   Dewpoint: 1.4°C
#   Mixing Ratio: 4.2 g/kg
#   Relative Humidity: 16.0%
#
# Föhn Effect:
#   Temperature increase: 10°C
#   Moisture loss: 3.8 g/kg
#   Result: Warm, dry conditions (RH < 20%)
# ...
